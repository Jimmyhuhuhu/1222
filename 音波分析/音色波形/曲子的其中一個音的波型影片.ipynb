# %%
import numpy as np
import librosa
import pygame
from pygame.locals import *

target_frequency = (158, 365)  # 包括中央C的頻率範圍
filename = r"D:\Temp\鋼琴.mp3"

# 載入音頻檔案
audio, sr = librosa.load(filename, sr=None)

# 執行短時傅立葉變換    
stft = np.abs(librosa.stft(audio, hop_length=512, n_fft=2048 * 8))  

# 初始化 pygame
pygame.init()

# 設置視窗大小
screen_width = 800
screen_height = 600
screen = pygame.display.set_mode((screen_width, screen_height))

# 設定震幅的最大值和最小值
max_amplitude = np.max(stft)
min_amplitude = np.min(stft)

# 定義每一幀的長度（以毫秒為單位）
frame_duration_ms = 10

# 設置時鐘對象
clock = pygame.time.Clock()

# 設置音頻
#pygame.mixer.init()
#pygame.mixer.music.load(filename)

# 開始播放音頻
#pygame.mixer.music.play()

time_data = []  # 時間數據
frequency_data = []  # 頻率數據
amplitude_data = []  # 振幅數據


# 设置刻度相关参数
scale_length = 20  # 刻度线长度
scale_spacing = 50  # 刻度线间距
scale_start = 50  # 刻度线起始位置
scale_end = screen_height - 50  # 刻度线结束位置（从下到上）
font = pygame.font.Font(None, 24)  # 字体和大小

# 遍历 stft 的每一帧，将其转换为视频中的一帧并播放
for i in range(stft.shape[1]):  # 使用 stft.shape[1] 作为时间轴的大小
    # 在这里添加你的 stft[:, i] 到视频中的处理代码
    # 例如，你可以根据 stft[:, i] 绘制一幅图像并显示在屏幕上
    # 这里简单地将 stft 的每一列作为一个折线图显示在屏幕上

    screen.fill((255, 255, 255))  # 清空屏幕，填充为白色

    # 缩放震幅到屏幕范围内
    scaled_stft = ((stft[:, i] - min_amplitude) / (max_amplitude - min_amplitude)) * screen_height-50
    
    # 将 stft 的每一列作为一个折线图显示在屏幕上
    points = [(j, screen_height - int(scaled_stft[j])) for j in range(stft.shape[0])]  # 构建折线图的点
    pygame.draw.lines(screen, (255, 0, 0), False, points, 4)  # 绘制折线图

    for y in range(scale_start, screen_height, scale_spacing):
        # 绘制刻度线
        pygame.draw.line(screen, (0, 0, 0), (scale_length, y), (0, y), 2)  # 左侧刻度线

        # 获取振幅值并将其转换为整数
        amplitude_value = int((scale_end - y) * (max_amplitude - min_amplitude) / (scale_end - scale_spacing) + min_amplitude)

        # 绘制振幅值文本
        text = font.render(str(amplitude_value), True, (0, 0, 0))  # 将文本渲染为图像
        text_rect = text.get_rect()  # 获取文本图像的矩形
        text_rect.center = (scale_length + 30, y)  # 设置文本图像的中心位置
        screen.blit(text, text_rect)  # 在屏幕上绘制文本图像

    # 更新屏幕
    pygame.display.flip()

    # 控制帧率
    clock.tick(1000 / frame_duration_ms)

    # 监听事件，例如点击关闭按钮等
    for event in pygame.event.get():
        if event.type == QUIT:
            pygame.quit()
            exit()

    # 找出每个窗口的最高振幅音
    max_frequency_index = np.argmax(stft[:, i])  # 找出当前窗口最高振幅的索引
    max_frequency = librosa.fft_frequencies(sr=sr, n_fft=2048*8)[max_frequency_index]  # 将索引转换为频率
    max_amplitude = stft[max_frequency_index, i]  # 获取最高振幅
    if max_amplitude < 3:
        max_amplitude = 1
    time_data.append(i+1),frequency_data.append(max_frequency),amplitude_data.append(max_amplitude)
    print(f"窗口{i+1}：频率为{max_frequency} Hz，振幅为{max_amplitude}")

    #f0 = librosa.yin(audio[i * 512:(i + 1) * 512], fmin=librosa.note_to_hz('C2'), fmax=librosa.note_to_hz('C7'))
    #f0 = f0[0] if f0.size > 0 else 0

    #max_amplitude = stft[:, i].max()  # 获取当前窗口的最高振幅

    # 输出每个窗口的信息
    #if max_amplitude < 3:
    #    max_amplitude = 1
    #time_data.append(i+1)
    #frequency_data.append(f0)
    #amplitude_data.append(max_amplitude)
    #print(f"time_data{i}：frequency_data{f0}，ampliude_data{max_amplitude}")


# 结束 pygame
pygame.quit()
print(len(frequency_data))
print(amplitude_data[100])
print(frequency_data[100])
# 使用 ffmpeg 将帧和音频合成为视频
#os.system(f"ffmpeg -y -r {fps} -f image2 -s 1920x1080 -i {output_dir}/frame%04d.png -i {filename} -c:v libx264 -pix_fmt yuv420p movie.mp4")
# Out:
# 窗口1：频率为659.1796875 Hz，振幅为1
# 窗口2：频率为659.1796875 Hz，振幅为1
# 窗口3：频率为659.1796875 Hz，振幅为1
# 窗口4：频率为659.1796875 Hz，振幅为1
# 窗口5：频率为659.1796875 Hz，振幅为1
# 窗口6：频率为659.1796875 Hz，振幅为1
# 窗口7：频率为659.1796875 Hz，振幅为1
# 窗口8：频率为659.1796875 Hz，振幅为1
# 窗口9：频率为659.1796875 Hz，振幅为1
# 窗口10：频率为659.1796875 Hz，振幅为1
# 窗口11：频率为659.1796875 Hz，振幅为1
# 窗口12：频率为659.1796875 Hz，振幅为3.0249240398406982
# 窗口13：频率为659.1796875 Hz，振幅为3.266350746154785
# 窗口14：频率为659.1796875 Hz，振幅为3.4940645694732666
# 窗口15：频率为659.1796875 Hz，振幅为3.7085747718811035
# 窗口16：频率为659.1796875 Hz，振幅为3.9087741374969482
# 窗口17：频率为659.1796875 Hz，振幅为4.093283176422119
# 窗口18：频率为659.1796875 Hz，振幅为4.261888027191162
# 窗口19：频率为659.1796875 Hz，振幅为4.413177490234375
# 窗口20：频率为659.1796875 Hz，振幅为4.543734073638916
# 窗口21：频率为659.1796875 Hz，振幅为4.651241779327393
# 窗口22：频率为659.1796875 Hz，振幅为4.733795166015625
# 窗口23：频率为659.1796875 Hz，振幅为4.791959285736084
# 窗口24：频率为659.1796875 Hz，振幅为4.82532262802124
# 窗口25：频率为659.1796875 Hz，振幅为4.8369927406311035
# 窗口26：频率为213.8671875 Hz，振幅为4.885737419128418
# 窗口27：频率为213.8671875 Hz，振幅为4.968797206878662
# 窗口28：频率为213.8671875 Hz，振幅为5.046642780303955
# 窗口29：频率为213.8671875 Hz，振幅为5.121784210205078
# 窗口30：频率为213.8671875 Hz，振幅为5.194808483123779
# 窗口31：频率为213.8671875 Hz，振幅为5.2655816078186035
# 窗口32：频率为213.8671875 Hz，振幅为5.323333263397217
# 窗口33：频率为213.8671875 Hz，振幅为5.355882167816162
# 窗口34：频率为213.8671875 Hz，振幅为5.352658748626709
# 窗口35：频率为213.8671875 Hz，振幅为5.301714897155762
# 窗口36：频率为213.8671875 Hz，振幅为5.196993827819824
# 窗口37：频率为213.8671875 Hz，振幅为5.054234027862549
# 窗口38：频率为213.8671875 Hz，振幅为4.630882740020752
# 窗口39：频率为216.796875 Hz，振幅为4.9095845222473145
# 窗口40：频率为266.6015625 Hz，振幅为10.981401443481445
# 窗口41：频率为266.6015625 Hz，振幅为22.57349395751953
# 窗口42：频率为266.6015625 Hz，振幅为40.314208984375
# 窗口43：频率为266.6015625 Hz，振幅为64.89877319335938
# 窗口44：频率为266.6015625 Hz，振幅为96.45893096923828
# 窗口45：频率为266.6015625 Hz，振幅为134.62371826171875
# 窗口46：频率为266.6015625 Hz，振幅为178.441162109375
# 窗口47：频率为266.6015625 Hz，振幅为226.4447479248047
# 窗口48：频率为263.671875 Hz，振幅为278.3495788574219
# 窗口49：频率为263.671875 Hz，振幅为337.1612854003906
# 窗口50：频率为263.671875 Hz，振幅为399.1065979003906
# 窗口51：频率为263.671875 Hz，振幅为462.6417236328125
# 窗口52：频率为263.671875 Hz，振幅为525.9230346679688
# 窗口53：频率为263.671875 Hz，振幅为587.2184448242188
# 窗口54：频率为263.671875 Hz，振幅为645.0239868164062
# 窗口55：频率为263.671875 Hz，振幅为697.989990234375
# 窗口56：频率为263.671875 Hz，振幅为745.01611328125
# 窗口57：频率为263.671875 Hz，振幅为785.2907104492188
# 窗口58：频率为263.671875 Hz，振幅为818.33251953125
# 窗口59：频率为263.671875 Hz，振幅为844.090087890625
# 窗口60：频率为263.671875 Hz，振幅为862.9010620117188
# 窗口61：频率为263.671875 Hz，振幅为875.6119384765625
# 窗口62：频率为263.671875 Hz，振幅为883.5823974609375
# 窗口63：频率为263.671875 Hz，振幅为888.5023193359375
# 窗口64：频率为260.7421875 Hz，振幅为902.4083251953125
# 窗口65：频率为260.7421875 Hz，振幅为924.1460571289062
# 窗口66：频率为260.7421875 Hz，振幅为941.4352416992188
# 窗口67：频率为260.7421875 Hz，振幅为953.8496704101562
# 窗口68：频率为260.7421875 Hz，振幅为960.9717407226562
# 窗口69：频率为260.7421875 Hz，振幅为962.4887084960938
# 窗口70：频率为260.7421875 Hz，振幅为958.5916137695312
# 窗口71：频率为263.671875 Hz，振幅为953.4369506835938
# 窗口72：频率为263.671875 Hz，振幅为959.1199951171875
# 窗口73：频率为263.671875 Hz，振幅为959.5657958984375
# 窗口74：频率为263.671875 Hz，振幅为954.4879760742188
# 窗口75：频率为263.671875 Hz，振幅为944.0977783203125
# 窗口76：频率为263.671875 Hz，振幅为928.93701171875
# 窗口77：频率为263.671875 Hz，振幅为909.8616333007812
# 窗口78：频率为263.671875 Hz，振幅为887.6934204101562
# 窗口79：频率为263.671875 Hz，振幅为863.2578735351562
# 窗口80：频率为260.7421875 Hz，振幅为845.99658203125
# 窗口81：频率为260.7421875 Hz，振幅为839.5891723632812
# 窗口82：频率为260.7421875 Hz，振幅为833.4967041015625
# 窗口83：频率为260.7421875 Hz，振幅为827.3577270507812
# 窗口84：频率为260.7421875 Hz，振幅为821.2601928710938
# 窗口85：频率为260.7421875 Hz，振幅为815.3087158203125
# 窗口86：频率为260.7421875 Hz，振幅为809.4219360351562
# 窗口87：频率为260.7421875 Hz，振幅为803.4856567382812
# 窗口88：频率为260.7421875 Hz，振幅为797.410888671875
# 窗口89：频率为260.7421875 Hz，振幅为791.2460327148438
# 窗口90：频率为260.7421875 Hz，振幅为785.17041015625
# 窗口91：频率为260.7421875 Hz，振幅为779.3674926757812
# 窗口92：频率为260.7421875 Hz，振幅为774.0037231445312
# 窗口93：频率为260.7421875 Hz，振幅为769.1103515625
# 窗口94：频率为260.7421875 Hz，振幅为764.5919189453125
# 窗口95：频率为260.7421875 Hz，振幅为760.362060546875
# 窗口96：频率为260.7421875 Hz，振幅为756.4263916015625
# 窗口97：频率为260.7421875 Hz，振幅为752.8140258789062
# 窗口98：频率为260.7421875 Hz，振幅为749.4115600585938
# 窗口99：频率为260.7421875 Hz，振幅为745.94140625
# 窗口100：频率为260.7421875 Hz，振幅为742.1530151367188
# 窗口101：频率为260.7421875 Hz，振幅为737.9894409179688
# 窗口102：频率为260.7421875 Hz，振幅为733.4515991210938
# 窗口103：频率为260.7421875 Hz，振幅为728.4682006835938
# 窗口104：频率为260.7421875 Hz，振幅为722.8309326171875
# 窗口105：频率为263.671875 Hz，振幅为726.1759033203125
# 窗口106：频率为263.671875 Hz，振幅为756.4653930664062
# 窗口107：频率为263.671875 Hz，振幅为782.3993530273438
# 窗口108：频率为263.671875 Hz，振幅为803.0462036132812
# 窗口109：频率为263.671875 Hz，振幅为817.710693359375
# 窗口110：频率为263.671875 Hz，振幅为826.0178833007812
# 窗口111：频率为263.671875 Hz，振幅为827.9722900390625
# 窗口112：频率为263.671875 Hz，振幅为823.9066162109375
# 窗口113：频率为263.671875 Hz，振幅为814.3154907226562
# 窗口114：频率为263.671875 Hz，振幅为799.6700439453125
# 窗口115：频率为263.671875 Hz，振幅为780.352783203125
# 窗口116：频率为263.671875 Hz，振幅为756.790283203125
# 窗口117：频率为263.671875 Hz，振幅为729.5964965820312
# 窗口118：频率为263.671875 Hz，振幅为699.6284790039062
# 窗口119：频率为263.671875 Hz，振幅为667.8856811523438
# 窗口120：频率为263.671875 Hz，振幅为635.3215942382812
# 窗口121：频率为263.671875 Hz，振幅为602.7664184570312
# 窗口122：频率为263.671875 Hz，振幅为570.9276733398438
# 窗口123：频率为263.671875 Hz，振幅为540.4599609375
# 窗口124：频率为263.671875 Hz，振幅为512.0977783203125
# 窗口125：频率为263.671875 Hz，振幅为486.5885009765625
# 窗口126：频率为263.671875 Hz，振幅为464.54351806640625
# 窗口127：频率为263.671875 Hz，振幅为446.35418701171875
# 窗口128：频率为263.671875 Hz，振幅为432.12060546875
# 窗口129：频率为263.671875 Hz，振幅为421.74224853515625
# 窗口130：频率为263.671875 Hz，振幅为415.02960205078125
# 窗口131：频率为263.671875 Hz，振幅为411.71295166015625
# 窗口132：频率为263.671875 Hz，振幅为411.345458984375
# 窗口133：频率为263.671875 Hz，振幅为413.2817687988281
# 窗口134：频率为263.671875 Hz，振幅为416.80877685546875
# 窗口135：频率为263.671875 Hz，振幅为421.29150390625
# 窗口136：频率为263.671875 Hz，振幅为426.263427734375
# 窗口137：频率为263.671875 Hz，振幅为431.41876220703125
# 窗口138：频率为263.671875 Hz，振幅为436.48797607421875
# 窗口139：频率为263.671875 Hz，振幅为441.2076416015625
# 窗口140：频率为263.671875 Hz，振幅为445.3658752441406
# 窗口141：频率为263.671875 Hz，振幅为448.8757019042969
# 窗口142：频率为263.671875 Hz，振幅为451.7718505859375
# 窗口143：频率为263.671875 Hz，振幅为454.1553955078125
# 窗口144：频率为263.671875 Hz，振幅为456.14752197265625
# 窗口145：频率为263.671875 Hz，振幅为457.8908386230469
# 窗口146：频率为263.671875 Hz，振幅为459.5604553222656
# 窗口147：频率为263.671875 Hz，振幅为461.35302734375
# 窗口148：频率为263.671875 Hz，振幅为463.4278259277344
# 窗口149：频率为263.671875 Hz，振幅为465.79986572265625
# 窗口150：频率为263.671875 Hz，振幅为468.3812561035156
# 窗口151：频率为263.671875 Hz，振幅为471.0683288574219
# 窗口152：频率为263.671875 Hz，振幅为473.7774963378906
# 窗口153：频率为263.671875 Hz，振幅为476.4458923339844
# 窗口154：频率为263.671875 Hz，振幅为478.9247741699219
# 窗口155：频率为263.671875 Hz，振幅为480.9337463378906
# 窗口156：频率为263.671875 Hz，振幅为482.159423828125
# 窗口157：频率为263.671875 Hz，振幅为482.34136962890625
# 窗口158：频率为263.671875 Hz，振幅为481.2927551269531
# 窗口159：频率为263.671875 Hz，振幅为478.90472412109375
# 窗口160：频率为263.671875 Hz，振幅为475.0783386230469
# 窗口161：频率为263.671875 Hz，振幅为469.7248840332031
# 窗口162：频率为263.671875 Hz，振幅为462.83380126953125
# 窗口163：频率为263.671875 Hz，振幅为454.4914245605469
# 窗口164：频率为263.671875 Hz，振幅为444.83966064453125
# 窗口165：频率为263.671875 Hz，振幅为434.0628356933594
# 窗口166：频率为263.671875 Hz，振幅为422.39300537109375
# 窗口167：频率为263.671875 Hz，振幅为410.11273193359375
# 窗口168：频率为260.7421875 Hz，振幅为402.4683837890625
# 窗口169：频率为260.7421875 Hz，振幅为395.9776916503906
# 窗口170：频率为260.7421875 Hz，振幅为389.2529602050781
# 窗口171：频率为260.7421875 Hz，振幅为382.37054443359375
# 窗口172：频率为260.7421875 Hz，振幅为375.41961669921875
# 窗口173：频率为260.7421875 Hz，振幅为368.4654235839844
# 窗口174：频率为260.7421875 Hz，振幅为361.54693603515625
# 窗口175：频率为260.7421875 Hz，振幅为354.7111511230469
# 窗口176：频率为260.7421875 Hz，振幅为347.99896240234375
# 窗口177：频率为260.7421875 Hz，振幅为341.4134826660156
# 窗口178：频率为260.7421875 Hz，振幅为334.9101867675781
# 窗口179：频率为260.7421875 Hz，振幅为328.3893127441406
# 窗口180：频率为260.7421875 Hz，振幅为321.7410888671875
# 窗口181：频率为260.7421875 Hz，振幅为314.9031982421875
# 窗口182：频率为263.671875 Hz，振幅为310.22198486328125
# 窗口183：频率为263.671875 Hz，振幅为307.131103515625
# 窗口184：频率为263.671875 Hz，振幅为303.2618713378906
# 窗口185：频率为263.671875 Hz，振幅为298.5625
# 窗口186：频率为263.671875 Hz，振幅为293.0254211425781
# 窗口187：频率为263.671875 Hz，振幅为286.6607971191406
# 窗口188：频率为263.671875 Hz，振幅为279.4931335449219
# 窗口189：频率为263.671875 Hz，振幅为271.5820617675781
# 窗口190：频率为263.671875 Hz，振幅为263.0702819824219
# 窗口191：频率为263.671875 Hz，振幅为254.15650939941406
# 窗口192：频率为263.671875 Hz，振幅为245.02606201171875
# 窗口193：频率为263.671875 Hz，振幅为235.8224639892578
# 窗口194：频率为263.671875 Hz，振幅为226.67984008789062
# 窗口195：频率为263.671875 Hz，振幅为217.72372436523438
# 窗口196：频率为263.671875 Hz，振幅为209.09129333496094
# 窗口197：频率为263.671875 Hz，振幅为200.91769409179688
# 窗口198：频率为263.671875 Hz，振幅为193.29611206054688
# 窗口199：频率为263.671875 Hz，振幅为186.28221130371094
# 窗口200：频率为263.671875 Hz，振幅为179.9130401611328
# 窗口201：频率为263.671875 Hz，振幅为174.2198944091797
# 窗口202：频率为263.671875 Hz，振幅为169.20590209960938
# 窗口203：频率为263.671875 Hz，振幅为164.86643981933594
# 窗口204：频率为263.671875 Hz，振幅为161.18943786621094
# 窗口205：频率为263.671875 Hz，振幅为158.14620971679688
# 窗口206：频率为263.671875 Hz，振幅为155.71884155273438
# 窗口207：频率为263.671875 Hz，振幅为153.87513732910156
# 窗口208：频率为263.671875 Hz，振幅为152.55130004882812
# 窗口209：频率为263.671875 Hz，振幅为151.67770385742188
# 窗口210：频率为263.671875 Hz，振幅为151.19676208496094
# 窗口211：频率为263.671875 Hz，振幅为151.04566955566406
# 窗口212：频率为263.671875 Hz，振幅为151.1546173095703
# 窗口213：频率为263.671875 Hz，振幅为151.4437713623047
# 窗口214：频率为263.671875 Hz，振幅为151.8229522705078
# 窗口215：频率为263.671875 Hz，振幅为152.22445678710938
# 窗口216：频率为263.671875 Hz，振幅为152.61643981933594
# 窗口217：频率为263.671875 Hz，振幅为152.98004150390625
# 窗口218：频率为263.671875 Hz，振幅为153.28309631347656
# 窗口219：频率为263.671875 Hz，振幅为153.5039825439453
# 窗口220：频率为263.671875 Hz，振幅为153.6346435546875
# 窗口221：频率为263.671875 Hz，振幅为153.70265197753906
# 窗口222：频率为263.671875 Hz，振幅为153.75103759765625
# 窗口223：频率为263.671875 Hz，振幅为153.81076049804688
# 窗口224：频率为263.671875 Hz，振幅为153.88658142089844
# 窗口225：频率为263.671875 Hz，振幅为153.97486877441406
# 窗口226：频率为260.7421875 Hz，振幅为154.49530029296875
# 窗口227：频率为260.7421875 Hz，振幅为156.1098175048828
# 窗口228：频率为260.7421875 Hz，振幅为157.2515869140625
# 窗口229：频率为260.7421875 Hz，振幅为157.92807006835938
# 窗口230：频率为260.7421875 Hz，振幅为158.1689910888672
# 窗口231：频率为260.7421875 Hz，振幅为157.9932403564453
# 窗口232：频率为260.7421875 Hz，振幅为157.40921020507812
# 窗口233：频率为260.7421875 Hz，振幅为156.4127960205078
# 窗口234：频率为260.7421875 Hz，振幅为155.0216522216797
# 窗口235：频率为263.671875 Hz，振幅为154.07052612304688
# 窗口236：频率为263.671875 Hz，振幅为153.26806640625
# 窗口237：频率为263.671875 Hz，振幅为152.1211395263672
# 窗口238：频率为263.671875 Hz，振幅为150.63258361816406
# 窗口239：频率为263.671875 Hz，振幅为148.84033203125
# 窗口240：频率为263.671875 Hz，振幅为146.7747039794922
# 窗口241：频率为263.671875 Hz，振幅为144.4503631591797
# 窗口242：频率为263.671875 Hz，振幅为141.86166381835938
# 窗口243：频率为263.671875 Hz，振幅为139.0231475830078
# 窗口244：频率为263.671875 Hz，振幅为135.9784393310547
# 窗口245：频率为263.671875 Hz，振幅为132.77890014648438
# 窗口246：频率为263.671875 Hz，振幅为129.46705627441406
# 窗口247：频率为263.671875 Hz，振幅为126.07508087158203
# 窗口248：频率为263.671875 Hz，振幅为122.62964630126953
# 窗口249：频率为263.671875 Hz，振幅为119.16483306884766
# 窗口250：频率为263.671875 Hz，振幅为115.71636962890625
# 窗口251：频率为263.671875 Hz，振幅为112.31623077392578
# 窗口252：频率为263.671875 Hz，振幅为108.97679138183594
# 窗口253：频率为263.671875 Hz，振幅为105.7048568725586
# 窗口254：频率为263.671875 Hz，振幅为102.52751922607422
# 窗口255：频率为263.671875 Hz，振幅为99.46893310546875
# 窗口256：频率为263.671875 Hz，振幅为96.52769470214844
# 窗口257：频率为263.671875 Hz，振幅为93.68604278564453
# 窗口258：频率为263.671875 Hz，振幅为90.92098236083984
# 窗口259：频率为263.671875 Hz，振幅为88.2214584350586
# 窗口260：频率为263.671875 Hz，振幅为85.59622192382812
# 窗口261：频率为263.671875 Hz，振幅为83.04326629638672
# 窗口262：频率为263.671875 Hz，振幅为80.53177642822266
# 窗口263：频率为263.671875 Hz，振幅为78.01744842529297
# 窗口264：频率为263.671875 Hz，振幅为75.481201171875
# 窗口265：频率为260.7421875 Hz，振幅为73.19940185546875
# 窗口266：频率为260.7421875 Hz，振幅为71.98966979980469
# 窗口267：频率为260.7421875 Hz，振幅为70.75261688232422
# 窗口268：频率为260.7421875 Hz，振幅为69.50782775878906
# 窗口269：频率为260.7421875 Hz，振幅为68.27926635742188
# 窗口270：频率为260.7421875 Hz，振幅为67.06919860839844
# 窗口271：频率为260.7421875 Hz，振幅为65.84477233886719
# 窗口272：频率为260.7421875 Hz，振幅为64.56653594970703
# 窗口273：频率为260.7421875 Hz，振幅为63.211181640625
# 窗口274：频率为524.4140625 Hz，振幅为61.997100830078125
# 窗口275：频率为524.4140625 Hz，振幅为60.724544525146484
# 窗口276：频率为524.4140625 Hz，振幅为59.36977767944336
# 窗口277：频率为524.4140625 Hz，振幅为57.95345687866211
# 窗口278：频率为524.4140625 Hz，振幅为56.495643615722656
# 窗口279：频率为524.4140625 Hz，振幅为55.024452209472656
# 窗口280：频率为524.4140625 Hz，振幅为53.55687713623047
# 窗口281：频率为524.4140625 Hz，振幅为52.10739517211914
# 窗口282：频率为524.4140625 Hz，振幅为50.6817741394043
# 窗口283：频率为524.4140625 Hz，振幅为49.27895736694336
# 窗口284：频率为524.4140625 Hz，振幅为47.89555740356445
# 窗口285：频率为524.4140625 Hz，振幅为46.5247802734375
# 窗口286：频率为524.4140625 Hz，振幅为45.15530014038086
# 窗口287：频率为524.4140625 Hz，振幅为43.780181884765625
# 窗口288：频率为524.4140625 Hz，振幅为42.39347457885742
# 窗口289：频率为524.4140625 Hz，振幅为40.985836029052734
# 窗口290：频率为524.4140625 Hz，振幅为39.54661178588867
# 窗口291：频率为524.4140625 Hz，振幅为38.07255172729492
# 窗口292：频率为524.4140625 Hz，振幅为36.55756759643555
# 窗口293：频率为524.4140625 Hz，振幅为35.00421905517578
# 窗口294：频率为524.4140625 Hz，振幅为33.4138069152832
# 窗口295：频率为524.4140625 Hz，振幅为31.7913875579834
# 窗口296：频率为524.4140625 Hz，振幅为30.152320861816406
# 窗口297：频率为524.4140625 Hz，振幅为28.50666618347168
# 窗口298：频率为524.4140625 Hz，振幅为26.859386444091797
# 窗口299：频率为524.4140625 Hz，振幅为25.22102928161621
# 窗口300：频率为260.7421875 Hz，振幅为26.507936477661133
# 窗口301：频率为260.7421875 Hz，振幅为29.97739601135254
# 窗口302：频率为260.7421875 Hz，振幅为33.42043685913086
# 窗口303：频率为260.7421875 Hz，振幅为36.8076057434082
# 窗口304：频率为260.7421875 Hz，振幅为40.111602783203125
# 窗口305：频率为260.7421875 Hz，振幅为43.31843185424805
# 窗口306：频率为260.7421875 Hz，振幅为46.4471435546875
# 窗口307：频率为260.7421875 Hz，振幅为49.522315979003906
# 窗口308：频率为260.7421875 Hz，振幅为52.56123733520508
# 窗口309：频率为260.7421875 Hz，振幅为55.55139923095703
# 窗口310：频率为260.7421875 Hz，振幅为58.46379470825195
# 窗口311：频率为260.7421875 Hz，振幅为61.27667236328125
# 窗口312：频率为260.7421875 Hz，振幅为63.98341751098633
# 窗口313：频率为260.7421875 Hz，振幅为66.5904769897461
# 窗口314：频率为260.7421875 Hz，振幅为69.08660125732422
# 窗口315：频率为260.7421875 Hz，振幅为71.44571685791016
# 窗口316：频率为260.7421875 Hz，振幅为73.62361145019531
# 窗口317：频率为260.7421875 Hz，振幅为75.59851837158203
# 窗口318：频率为260.7421875 Hz，振幅为77.36346435546875
# 窗口319：频率为260.7421875 Hz，振幅为78.93339538574219
# 窗口320：频率为260.7421875 Hz，振幅为80.31204223632812
# 窗口321：频率为260.7421875 Hz，振幅为81.48133087158203
# 窗口322：频率为260.7421875 Hz，振幅为82.40872192382812
# 窗口323：频率为260.7421875 Hz，振幅为83.0700454711914
# 窗口324：频率为260.7421875 Hz，振幅为83.46586608886719
# 窗口325：频率为260.7421875 Hz，振幅为83.603759765625
# 窗口326：频率为260.7421875 Hz，振幅为83.49881744384766
# 窗口327：频率为260.7421875 Hz，振幅为83.15303039550781
# 窗口328：频率为260.7421875 Hz，振幅为82.56636810302734
# 窗口329：频率为260.7421875 Hz，振幅为81.72994232177734
# 窗口330：频率为260.7421875 Hz，振幅为80.63610076904297
# 窗口331：频率为260.7421875 Hz，振幅为79.29981994628906
# 窗口332：频率为260.7421875 Hz，振幅为77.75689697265625
# 窗口333：频率为260.7421875 Hz，振幅为76.04219055175781
# 窗口334：频率为260.7421875 Hz，振幅为74.17316436767578
# 窗口335：频率为260.7421875 Hz，振幅为72.15827178955078
# 窗口336：频率为260.7421875 Hz，振幅为70.00230407714844
# 窗口337：频率为260.7421875 Hz，振幅为67.72520446777344
# 窗口338：频率为260.7421875 Hz，振幅为65.37214660644531
# 窗口339：频率为260.7421875 Hz，振幅为62.980133056640625
# 窗口340：频率为260.7421875 Hz，振幅为60.56132888793945
# 窗口341：频率为260.7421875 Hz，振幅为58.082828521728516
# 窗口342：频率为260.7421875 Hz，振幅为55.50272750854492
# 窗口343：频率为260.7421875 Hz，振幅为52.81379699707031
# 窗口344：频率为263.671875 Hz，振幅为50.23792266845703
# 窗口345：频率为263.671875 Hz，振幅为48.93999481201172
# 窗口346：频率为263.671875 Hz，振幅为47.94110107421875
# 窗口347：频率为263.671875 Hz，振幅为47.261905670166016
# 窗口348：频率为263.671875 Hz，振幅为46.87246322631836
# 窗口349：频率为263.671875 Hz，振幅为46.67136001586914
# 窗口350：频率为263.671875 Hz，振幅为46.537296295166016
# 窗口351：频率为263.671875 Hz，振幅为46.37387466430664
# 窗口352：频率为263.671875 Hz，振幅为46.11703109741211
# 窗口353：频率为263.671875 Hz，振幅为45.71668243408203
# 窗口354：频率为263.671875 Hz，振幅为45.14799499511719
# 窗口355：频率为263.671875 Hz，振幅为44.41718292236328
# 窗口356：频率为263.671875 Hz，振幅为43.51008987426758
# 窗口357：频率为263.671875 Hz，振幅为42.41474151611328
# 窗口358：频率为263.671875 Hz，振幅为41.100711822509766
# 窗口359：频率为263.671875 Hz，振幅为39.53783416748047
# 窗口360：频率为263.671875 Hz，振幅为37.712947845458984
# 窗口361：频率为263.671875 Hz，振幅为35.64458084106445
# 窗口362：频率为263.671875 Hz，振幅为33.36591720581055
# 窗口363：频率为263.671875 Hz，振幅为30.91827392578125
# 窗口364：频率为263.671875 Hz，振幅为28.35032081604004
# 窗口365：频率为263.671875 Hz，振幅为25.7004337310791
# 窗口366：频率为263.671875 Hz，振幅为22.990093231201172
# 窗口367：频率为263.671875 Hz，振幅为20.24825668334961
# 窗口368：频率为263.671875 Hz，振幅为17.503087997436523
# 窗口369：频率为263.671875 Hz，振幅为14.796527862548828
# 窗口370：频率为263.671875 Hz，振幅为12.193917274475098
# 窗口371：频率为263.671875 Hz，振幅为9.765680313110352
# 窗口372：频率为260.7421875 Hz，振幅为8.066842079162598
# 窗口373：频率为254.8828125 Hz，振幅为7.389588832855225
# 窗口374：频率为254.8828125 Hz，振幅为7.316277503967285
# 窗口375：频率为254.8828125 Hz，振幅为7.104481220245361
# 窗口376：频率为254.8828125 Hz，振幅为6.7038140296936035
# 窗口377：频率为254.8828125 Hz，振幅为6.164170742034912
# 窗口378：频率为254.8828125 Hz，振幅为5.598008155822754
# 窗口379：频率为251.953125 Hz，振幅为5.284052848815918
# 窗口380：频率为251.953125 Hz，振幅为4.968526363372803
# 窗口381：频率为263.671875 Hz，振幅为4.939091682434082
# 窗口382：频率为263.671875 Hz，振幅为5.490011215209961
# 窗口383：频率为263.671875 Hz，振幅为5.893404483795166
# 窗口384：频率为263.671875 Hz，振幅为6.168445110321045
# 窗口385：频率为263.671875 Hz，振幅为6.325164794921875
# 窗口386：频率为263.671875 Hz，振幅为6.381783962249756
# 窗口387：频率为263.671875 Hz，振幅为6.357377529144287
# 窗口388：频率为263.671875 Hz，振幅为6.259255886077881
# 窗口389：频率为263.671875 Hz，振幅为6.092811107635498
# 窗口390：频率为263.671875 Hz，振幅为5.855766773223877
# 窗口391：频率为263.671875 Hz，振幅为5.544417858123779
# 窗口392：频率为263.671875 Hz，振幅为5.168876647949219
# 窗口393：频率为263.671875 Hz，振幅为4.743805408477783
# 窗口394：频率为263.671875 Hz，振幅为4.289722919464111
# 窗口395：频率为49.8046875 Hz，振幅为3.879824161529541
# 窗口396：频率为49.8046875 Hz，振幅为3.557102918624878
# 窗口397：频率为49.8046875 Hz，振幅为3.2077014446258545
# 窗口398：频率为49.8046875 Hz，振幅为1
# 窗口399：频率为49.8046875 Hz，振幅为1
# 399
# 737.98944
# 260.7421875

# %%
replacement_value = 800
start_index = 250
end_index = 650
replacement_list = [replacement_value] * (end_index - start_index)
print(replacement_list)

# 确保替换列表的长度与要替换的范围的长度相同
if len(replacement_list) == end_index - start_index:
    # 使用切片赋值将替换列表中的元素替换为原始列表中的元素
    amplitude_data[start_index:end_index] = replacement_list

# 打印替换后的列表
for i in amplitude_data:
    print('震幅為:',i)  # 输出：[1, 2, 10, 11, 12, 6, 7, 8, 9]
# Out:
# [800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800, 800]
# 震幅為: 1
# 震幅為: 1
# 震幅為: 1
# 震幅為: 1
# 震幅為: 1
# 震幅為: 1
# 震幅為: 1
# 震幅為: 1
# 震幅為: 1
# 震幅為: 1
# 震幅為: 1
# 震幅為: 3.024924
# 震幅為: 3.2663507
# 震幅為: 3.4940646
# 震幅為: 3.7085748
# 震幅為: 3.9087741
# 震幅為: 4.093283
# 震幅為: 4.261888
# 震幅為: 4.4131775
# 震幅為: 4.543734
# 震幅為: 4.651242
# 震幅為: 4.733795
# 震幅為: 4.7919593
# 震幅為: 4.8253226
# 震幅為: 4.8369927
# 震幅為: 4.8857374
# 震幅為: 4.968797
# 震幅為: 5.046643
# 震幅為: 5.121784
# 震幅為: 5.1948085
# 震幅為: 5.2655816
# 震幅為: 5.3233333
# 震幅為: 5.355882
# 震幅為: 5.3526587
# 震幅為: 5.301715
# 震幅為: 5.196994
# 震幅為: 5.054234
# 震幅為: 4.6308827
# 震幅為: 4.9095845
# 震幅為: 10.981401
# 震幅為: 22.573494
# 震幅為: 40.31421
# 震幅為: 64.89877
# 震幅為: 96.45893
# 震幅為: 134.62372
# 震幅為: 178.44116
# 震幅為: 226.44475
# 震幅為: 278.34958
# 震幅為: 337.1613
# 震幅為: 399.1066
# 震幅為: 462.64172
# 震幅為: 525.92303
# 震幅為: 587.21844
# 震幅為: 645.024
# 震幅為: 697.99
# 震幅為: 745.0161
# 震幅為: 785.2907
# 震幅為: 818.3325
# 震幅為: 844.0901
# 震幅為: 862.90106
# 震幅為: 875.61194
# 震幅為: 883.5824
# 震幅為: 888.5023
# 震幅為: 902.4083
# 震幅為: 924.14606
# 震幅為: 941.43524
# 震幅為: 953.8497
# 震幅為: 960.97174
# 震幅為: 962.4887
# 震幅為: 958.5916
# 震幅為: 953.43695
# 震幅為: 959.12
# 震幅為: 959.5658
# 震幅為: 954.488
# 震幅為: 944.0978
# 震幅為: 928.937
# 震幅為: 909.86163
# 震幅為: 887.6934
# 震幅為: 863.2579
# 震幅為: 845.9966
# 震幅為: 839.5892
# 震幅為: 833.4967
# 震幅為: 827.3577
# 震幅為: 821.2602
# 震幅為: 815.3087
# 震幅為: 809.42194
# 震幅為: 803.48566
# 震幅為: 797.4109
# 震幅為: 791.24603
# 震幅為: 785.1704
# 震幅為: 779.3675
# 震幅為: 774.0037
# 震幅為: 769.11035
# 震幅為: 764.5919
# 震幅為: 760.36206
# 震幅為: 756.4264
# 震幅為: 752.814
# 震幅為: 749.41156
# 震幅為: 745.9414
# 震幅為: 742.153
# 震幅為: 737.98944
# 震幅為: 733.4516
# 震幅為: 728.4682
# 震幅為: 722.83093
# 震幅為: 726.1759
# 震幅為: 756.4654
# 震幅為: 782.39935
# 震幅為: 803.0462
# 震幅為: 817.7107
# 震幅為: 826.0179
# 震幅為: 827.9723
# 震幅為: 823.9066
# 震幅為: 814.3155
# 震幅為: 799.67004
# 震幅為: 780.3528
# 震幅為: 756.7903
# 震幅為: 729.5965
# 震幅為: 699.6285
# 震幅為: 667.8857
# 震幅為: 635.3216
# 震幅為: 602.7664
# 震幅為: 570.9277
# 震幅為: 540.45996
# 震幅為: 512.0978
# 震幅為: 486.5885
# 震幅為: 464.54352
# 震幅為: 446.3542
# 震幅為: 432.1206
# 震幅為: 421.74225
# 震幅為: 415.0296
# 震幅為: 411.71295
# 震幅為: 411.34546
# 震幅為: 413.28177
# 震幅為: 416.80878
# 震幅為: 421.2915
# 震幅為: 426.26343
# 震幅為: 431.41876
# 震幅為: 436.48798
# 震幅為: 441.20764
# 震幅為: 445.36588
# 震幅為: 448.8757
# 震幅為: 451.77185
# 震幅為: 454.1554
# 震幅為: 456.14752
# 震幅為: 457.89084
# 震幅為: 459.56046
# 震幅為: 461.35303
# 震幅為: 463.42783
# 震幅為: 465.79987
# 震幅為: 468.38126
# 震幅為: 471.06833
# 震幅為: 473.7775
# 震幅為: 476.4459
# 震幅為: 478.92477
# 震幅為: 480.93375
# 震幅為: 482.15942
# 震幅為: 482.34137
# 震幅為: 481.29276
# 震幅為: 478.90472
# 震幅為: 475.07834
# 震幅為: 469.72488
# 震幅為: 462.8338
# 震幅為: 454.49142
# 震幅為: 444.83966
# 震幅為: 434.06284
# 震幅為: 422.393
# 震幅為: 410.11273
# 震幅為: 402.46838
# 震幅為: 395.9777
# 震幅為: 389.25296
# 震幅為: 382.37054
# 震幅為: 375.41962
# 震幅為: 368.46542
# 震幅為: 361.54694
# 震幅為: 354.71115
# 震幅為: 347.99896
# 震幅為: 341.41348
# 震幅為: 334.9102
# 震幅為: 328.3893
# 震幅為: 321.7411
# 震幅為: 314.9032
# 震幅為: 310.222
# 震幅為: 307.1311
# 震幅為: 303.26187
# 震幅為: 298.5625
# 震幅為: 293.02542
# 震幅為: 286.6608
# 震幅為: 279.49313
# 震幅為: 271.58206
# 震幅為: 263.07028
# 震幅為: 254.15651
# 震幅為: 245.02606
# 震幅為: 235.82246
# 震幅為: 226.67984
# 震幅為: 217.72372
# 震幅為: 209.0913
# 震幅為: 200.9177
# 震幅為: 193.29611
# 震幅為: 186.28221
# 震幅為: 179.91304
# 震幅為: 174.2199
# 震幅為: 169.2059
# 震幅為: 164.86644
# 震幅為: 161.18944
# 震幅為: 158.14621
# 震幅為: 155.71884
# 震幅為: 153.87514
# 震幅為: 152.5513
# 震幅為: 151.6777
# 震幅為: 151.19676
# 震幅為: 151.04567
# 震幅為: 151.15462
# 震幅為: 151.44377
# 震幅為: 151.82295
# 震幅為: 152.22446
# 震幅為: 152.61644
# 震幅為: 152.98004
# 震幅為: 153.2831
# 震幅為: 153.50398
# 震幅為: 153.63464
# 震幅為: 153.70265
# 震幅為: 153.75104
# 震幅為: 153.81076
# 震幅為: 153.88658
# 震幅為: 153.97487
# 震幅為: 154.4953
# 震幅為: 156.10982
# 震幅為: 157.25159
# 震幅為: 157.92807
# 震幅為: 158.16899
# 震幅為: 157.99324
# 震幅為: 157.40921
# 震幅為: 156.4128
# 震幅為: 155.02165
# 震幅為: 154.07053
# 震幅為: 153.26807
# 震幅為: 152.12114
# 震幅為: 150.63258
# 震幅為: 148.84033
# 震幅為: 146.7747
# 震幅為: 144.45036
# 震幅為: 141.86166
# 震幅為: 139.02315
# 震幅為: 135.97844
# 震幅為: 132.7789
# 震幅為: 129.46706
# 震幅為: 126.07508
# 震幅為: 122.62965
# 震幅為: 119.16483
# 震幅為: 115.71637
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800
# 震幅為: 800

# %%
import math
def freq_to_note(freq):
    # 基準音 A4 的頻率（在西方音樂中，A4 是440 Hz）
    A4_freq = 440.0
    # 半音間隔的比例常數
    semitone_ratio = 2 ** (1/12)
    
    # 計算音高相對於 A4 的半音數
    num_semitones = 12 * math.log2(int(freq) / A4_freq)
    # 將半音數四捨五入到最接近的整數
    num_semitones_rounded = round(num_semitones)
    
    # 定義音名列表（包括升降號）
    note_names = ["A", "A#", "B", "C", "C#", "D", "D#", "E", "F", "F#", "G", "G#"]
    
    # 計算音名
    note_index = num_semitones_rounded % 12
    octave = 4 + num_semitones_rounded // 12
    
    return note_names[note_index] + str(octave)

import numpy as np
note_to_semitone = {
    'C': 0,
    'C#': 1, 'Db': 1,
    'D': 2,
    'D#': 3, 'Eb': 3,
    'E': 4,
    'F': 5,
    'F#': 6, 'Gb': 6,
    'G': 7,
    'G#': 8, 'Ab': 8,
    'A': 9,
    'A#': 10, 'Bb': 10,
    'B': 11
}

def note_to_freq(note):
    # 提取音名和八度
    if len(note) == 3:  # like C#4 or Db4
        note_name = note[:2]
        octave = int(note[2])
    else:  # like C4
        note_name = note[0]
        octave = int(note[1])
    
    # 計算相對於C0的半音數
    semitone_offset = note_to_semitone[note_name]
    
    # 計算MIDI音高數
    midi_number = semitone_offset + (octave + 1) * 12
    
    return 440.0 * (2 ** ((midi_number - 69) / 12))


print(note_to_freq('B3'))
print(note_to_freq('C#4'))
print(freq_to_note(260))
# Out:
# 246.94165062806206
# 277.1826309768721
# C3

# %%
notes = ["C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"]
note_list = [note + str(octave) for octave in range(1, 9) for note in notes]

def get_note(value):
    try:
        # 找到指定音符的索引
        index = note_list.index(value)
        # 如果索引为0，说明是第一个音符，没有前一个音符
        if index == 0:
            return None
        else:
            # 返回前一个音符
            return [note_list[index - 1],note_list[index + 1]]
    except ValueError:
        # 如果指定音符不在列表中，返回None
        return None
print(get_note('D5'))
# Out:
# ['C#5', 'D#5']

# %%
replacement_value = 'E3'
value = 'C4'
def change_pitch(replacement_value, value):
    print(get_note(value))
    print(note_to_freq(get_note(value)[0]))
    print(note_to_freq(get_note(value)[1]))
    try:
        for idx in range(200):  # 假设范围是100到200
            freq = frequency_data[idx]
            if freq > note_to_freq(get_note(value)[0]) and freq < note_to_freq(get_note(value)[1]):
                print(f'把頻率{freq}的音改為{note_to_freq(replacement_value)}')
                frequency_data[idx] = note_to_freq(replacement_value)
                #print(frequency[idx])
    except ValueError:
        return None

print(change_pitch(replacement_value, value))

# 输出修改后的列表
# Out:
# ['B3', 'C#4']
# 246.94165062806206
# 277.1826309768721
# 把頻率261.84557346256的音改為164.81377845643496
# 把頻率274.6375094761715的音改為164.81377845643496
# 把頻率273.3660844460788的音改為164.81377845643496
# 把頻率256.1668914617507的音改為164.81377845643496
# 把頻率264.46963080149396的音改為164.81377845643496
# 把頻率259.44447402268077的音改為164.81377845643496
# 把頻率258.43530579407314的音改為164.81377845643496
# None

# %%
replacement_value = 'E3'
start_index = 50
end_index = 350
replacement_list = [replacement_value] * (end_index - start_index)
print(replacement_list)


 #确保替换列表的长度与要替换的范围的长度相同
if len(replacement_list) == end_index - start_index:
    # 使用切片赋值将替换列表中的元素替换为原始列表中的元素
    frequency_data[start_index:end_index] = replacement_list

# 打印替换后的列表
#print(frequency_data)  # 输出：[1, 2, 10, 11, 12, 6, 7, 8, 9]
# Out:
# ['B2', 'C#3']

# %%
import numpy as np

import librosa
from IPython.display import Audio
print(frequency_data)
def generate_audio(frequency_data, amplitude_data, time_data, sample_rate=44100):
    # 將頻率和振幅數據堆疊為二維數組
    freq_ampl_nparray = np.vstack((frequency_data, amplitude_data))
    
    # 確定時間窗口的長度和跳躍長度
    hop_length = 512
    win_length = 2048

    # 初始化音頻數據
    audio_data = np.zeros((len(time_data) * hop_length + win_length))

    # 將每個時間窗口的頻率和振幅轉換為時間域信號
    for i, (frequency, amplitude) in enumerate(zip(*freq_ampl_nparray)):
        # 計算時間窗口的起始樣本位置
        start_sample = i * hop_length
        # 計算每個時間窗口的時間軸
        time_axis = np.arange(start_sample, start_sample + win_length)
        # 計算正弦波信號
        sin_wave = amplitude * np.sin(2 * np.pi * frequency * time_axis / sample_rate)
        # 添加到總音頻數據中
        audio_data[start_sample:start_sample + win_length] += sin_wave

    # 顯示音頻
    return audio_data

def normalize_amplitude(amplitude_data):
    # 將振幅數據縮放到0到1之間
    max_amplitude = np.max(amplitude_data)
    min_amplitude = np.min(amplitude_data)
    normalized_amplitude = (amplitude_data - min_amplitude) / (max_amplitude - min_amplitude)
    return normalized_amplitude

# 調用函數正確縮放振幅數據
normalized_amplitude_data = normalize_amplitude(amplitude_data)

# 使用更新的振幅數據生成音頻
audio_data = generate_audio(frequency_data, normalized_amplitude_data, time_data)
Audio(data=audio_data, rate=44100)
# Out:
# [659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 659.1796875, 213.8671875, 213.8671875, 213.8671875, 213.8671875, 213.8671875, 213.8671875, 213.8671875, 213.8671875, 213.8671875, 213.8671875, 213.8671875, 213.8671875, 213.8671875, 216.796875, 266.6015625, 266.6015625, 266.6015625, 266.6015625, 266.6015625, 266.6015625, 266.6015625, 266.6015625, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 263.671875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 524.4140625, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 260.7421875, 26 ...
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np
import librosa
import soundfile as sf

# 讀取音頻信息
sr = 44100  # 假設采樣率為22050 Hz
n_fft = 2048 * 8
hop_length = 512



# 初始化一個空的STFT矩陣，用於存儲處理後的頻率和振幅數據
reconstructed_stft = np.zeros((n_fft//2 + 1, len(frequency_data)), dtype=np.complex64)

for i in range(len(frequency_data)):
    max_frequency = frequency_data[i]
    max_amplitude = amplitude_data[i]
    
    # 找到與max_frequency最接近的頻率索引
    freq_idx = np.argmin(np.abs(librosa.fft_frequencies(sr=sr, n_fft=n_fft) - max_frequency))
    
    # 重建STFT矩陣
    reconstructed_stft[freq_idx, i] = max_amplitude * np.exp(1j * phase[freq_idx, i])

# 進行逆STFT
reconstructed_audio = librosa.istft(reconstructed_stft, hop_length=hop_length)

# 保存處理後的音頻
output_path = r"D:\Temp\reconstructed_audio_file.wav"
sf.write(output_path, reconstructed_audio, sr)

# 如果需要播放音頻，可以使用以下代碼（需要安裝IPython.display）
from IPython.display import Audio
Audio(data=reconstructed_audio, rate=sr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 23
#      20     freq_idx = np.argmin(np.abs(librosa.fft_frequencies(sr=sr, n_fft=n_fft) - max_frequency))
#      22     # 重建STFT矩陣
# ---> 23     reconstructed_stft[freq_idx, i] = max_amplitude * np.exp(1j * phase[freq_idx, i])
#      25 # 進行逆STFT
#      26 reconstructed_audio = librosa.istft(reconstructed_stft, hop_length=hop_length)
#
# NameError: name 'phase' is not defined
